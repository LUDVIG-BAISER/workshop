# %% [markdown]
# # Вступление и описание работы

# %% [markdown]
# ## Импорт необходимых библиотек и объявление констант

# %%
pip install phik -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Catboost -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error
import ta
import os
import phik

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.pipeline import Pipeline

from sklearn.model_selection import (train_test_split,
                                     RandomizedSearchCV,
                                     GridSearchCV)


from sklearn.preprocessing import (StandardScaler,
                                   RobustScaler,
                                   MinMaxScaler,
                                   OrdinalEncoder,
                                   OneHotEncoder)


from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

from sklearn.metrics import (make_scorer,
                             mean_absolute_error,
                             roc_auc_score,
                             f1_score,
                             precision_score,
                             accuracy_score,
                             recall_score, 
                             classification_report, 
                             confusion_matrix,
                             precision_recall_curve, 
                             average_precision_score,
                             mean_squared_error)


from sklearn.inspection import permutation_importance
from xgboost import XGBClassifier

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

import scipy.stats as stats


from catboost import CatBoostClassifier
from sklearn.dummy import DummyClassifier

import os
import phik


TEST_SIZE = 0.25
RANDOM_STATE = 666

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format','{:.4f}'.format)

# %% [markdown]
# # Загрузка данных и ознакомление с ними

# %%
df_train = pd.read_csv('heart_train.csv')
df_test = pd.read_csv('heart_test.csv')

# %%
df_train.shape
# Out:
# (8685, 28)

# %%
df_train.head()
# Out:
#    Unnamed: 0    Age  Cholesterol  Heart rate  Diabetes  Family History  \
# 0           0 0.3596       0.7321      0.0742    1.0000          1.0000
# 1           1 0.2022       0.3250      0.0477    1.0000          1.0000
# 2           2 0.6067       0.8607      0.0559    1.0000          0.0000
# 3           3 0.7303       0.0071      0.0532    0.0000          0.0000
# 4           4 0.7753       0.7571      0.0220    0.0000          0.0000
#
#    Smoking  Obesity  Alcohol Consumption  Exercise Hours Per Week  Diet  \
# 0   1.0000   1.0000               1.0000                   0.5355     1
# 1   0.0000   0.0000               1.0000                   0.0687     2
# 2   1.0000   1.0000               1.0000                   0.9440     2
# 3   1.0000   0.0000               1.0000                   0.6970     0
# 4   1.0000   0.0000               1.0000                   0.4129     1
#
#    Previous Heart Problems  Medication Use  Stress Level  \
# 0                   1.0000          0.0000        8.0000
# 1                   1.0000          0.0000        9.0000
# 2                   1.0000          1.0000        6.0000
# 3                   0.0000          1.0000        3.0000
# 4                   0.0000          0.0000        8.0000
#
#    Sedentary Hours Per Day  Income    BMI  Triglycerides  \
# 0                   0.2257  0.1059 0.4592         0.9792
# 1                   0.2899  0.1642 0.1171         0.5156
# 2                   0.5501  0.5987 0.3736         0.0130
# 3                   0.3310  0.0776 0.0497         0.1312
# 4                   0.5246  0.3420 0.8304         0.0701
#
#    Physical Activity Days Per Week  Sleep Hours Per Day  \
# 0                           3.0000               0.3333
# 1                           3.0000               0.8333
# 2                           2.0000               1.0000
# 3                           0.0000               0.3333
# 4                           5.0000               1.0000
#
#    Heart Attack Risk (Binary)  Blood sugar  CK-MB  Troponin  Gender  \
# 0                      0.0000       0.2270 0.0482    0.0365    Male
# 1                      0.0000       0.1502 0.0176    0.0002  Female
# 2                      0.0000       0.2270 0.0482    0.0365  Female
# 3                      1.0000       0.2270 0.0482    0.0365  Female
# 4                      1.0000       0.2270 0.0482    0.0365    Male
#
#    Systolic blood pressure  Diastolic blood pressure    id
# 0                   0.2129                    0.7093  2664
# 1                   0.4129                    0.5698  9287
# 2                   0.2387                    0.2209  5379
# 3                   0.3484                    0.2674  8222
# 4                   0.6194                    0.4419  4047

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8685 entries, 0 to 8684
# Data columns (total 28 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       8685 non-null   int64
#  1   Age                              8685 non-null   float64
#  2   Cholesterol                      8685 non-null   float64
#  3   Heart rate                       8685 non-null   float64
#  4   Diabetes                         8442 non-null   float64
#  5   Family History                   8442 non-null   float64
#  6   Smoking                          8442 non-null   float64
#  7   Obesity                          8442 non-null   float64
#  8   Alcohol Consumption              8442 non-null   float64
#  9   Exercise Hours Per Week          8685 non-null   float64
#  10  Diet                             8685 non-null   int64
#  11  Previous Heart Problems          8442 non-null   float64
#  12  Medication Use                   8442 non-null   float64
#  13  Stress Level                     8442 non-null   float64
#  14  Sedentary Hours Per Day          8685 non-null   float64
#  15  Income                           8685 non-null   float64
#  16  BMI                              8685 non-null   float64
#  17  Triglycerides                    8685 non-null   float64
#  18  Physical Activity Days Per Week  8442 non-null   float64
#  19  Sleep Hours Per Day              8685 non-null   float64
#  20  Heart Attack Risk (Binary)       8685 non-null   float64
#  21  Blood sugar                      8685 non-null   float64
#  22  CK-MB                            8685 non-null   float64
#  23  Troponin                         8685 non-null   float64
#  24  Gender                           8685 non-null   object
#  25  Systolic blood pressure          8685 non-null   float64
#  26  Diastolic blood pressure         8685 non-null   float64
#  27  id                               8685 non-null   int64
# dtypes: float64(24), int64(3), object(1)
# memory usage: 1.9+ MB

# %%
df_train.describe()
# Out:
#        Unnamed: 0       Age  Cholesterol  Heart rate  Diabetes  \
# count   8685.0000 8685.0000    8685.0000   8685.0000 8442.0000
# mean    4342.0000    0.4500       0.5011      0.0507    0.6521
# std     2507.2879    0.2312       0.2847      0.0235    0.4763
# min        0.0000    0.0000       0.0000      0.0000    0.0000
# 25%     2171.0000    0.2584       0.2679      0.0348    0.0000
# 50%     4342.0000    0.4607       0.4998      0.0504    1.0000
# 75%     6513.0000    0.6404       0.7464      0.0660    1.0000
# max     8684.0000    1.0000       1.0000      1.0000    1.0000
#
#        Family History   Smoking   Obesity  Alcohol Consumption  \
# count       8442.0000 8442.0000 8442.0000            8442.0000
# mean           0.4896    0.9029    0.4983               0.6020
# std            0.4999    0.2962    0.5000               0.4895
# min            0.0000    0.0000    0.0000               0.0000
# 25%            0.0000    1.0000    0.0000               0.0000
# 50%            0.0000    1.0000    0.0000               1.0000
# 75%            1.0000    1.0000    1.0000               1.0000
# max            1.0000    1.0000    1.0000               1.0000
#
#        Exercise Hours Per Week      Diet  Previous Heart Problems  \
# count                8685.0000 8685.0000                8442.0000
# mean                    0.5034    1.0575                   0.4954
# std                     0.2848    0.8666                   0.5000
# min                     0.0000    0.0000                   0.0000
# 25%                     0.2633    0.0000                   0.0000
# 50%                     0.5021    1.0000                   0.0000
# 75%                     0.7487    2.0000                   1.0000
# max                     1.0000    3.0000                   1.0000
#
#        Medication Use  Stress Level  Sedentary Hours Per Day    Income  \
# count       8442.0000     8442.0000                8685.0000 8685.0000
# mean           0.5012        5.4934                   0.4992    0.4961
# std            0.5000        2.8679                   0.2853    0.2847
# min            0.0000        1.0000                   0.0000    0.0000
# 25%            0.0000        3.0000                   0.2559    0.2519
# 50%            1.0000        5.0000                   0.4999    0.4949
# 75%            1.0000        8.0000                   0.7446    0.7410
# max            1.0000       10.0000                   1.0000    1.0000
#
#             BMI  Triglycerides  Physical Activity Days Per Week  \
# count 8685.0000      8685.0000                        8442.0000
# mean     0.4968         0.5055                           3.5083
# std      0.2826         0.2863                           2.2818
# min      0.0000         0.0000                           0.0000
# 25%      0.2542         0.2636                           2.0000
# 50%      0.4948         0.5036                           3.0000
# 75%      0.7370         0.7506                           6.0000
# max      1.0000         1.0000                           7.0000
#
#        Sleep Hours Per Day  Heart Attack Risk (Binary)  Blood sugar     CK-MB  \
# count            8685.0000                   8685.0000    8685.0000 8685.0000
# mean                0.5037                      0.3469       0.2273    0.0482
# std                 0.3281                      0.4760       0.0766    0.0755
# min                 0.0000                      0.0000       0.0000    0.0000
# 25%                 0.1667                      0.0000       0.2270    0.0482
# 50%                 0.5000                      0.0000       0.2270    0.0482
# 75%                 0.8333                      1.0000       0.2270    0.0482
# max                 1.0000                      1.0000       1.0000    1.0000
#
#        Troponin  Systolic blood pressure  Diastolic blood pressure        id
# count 8685.0000                8685.0000                 8685.0000 8685.0000
# mean     0.0367                   0.4503                    0.4976 4831.2108
# std      0.0602                   0.1702                    0.1718 2782.5856
# min      0.0000                   0.0000                    0.0000    1.0000
# 25%      0.0365                   0.3032                    0.3488 2425.0000
# 50%      0.0365                   0.4452                    0.5000 4837.0000
# 75%      0.0365                   0.6000                    0.6512 7242.0000
# max      1.0000                   1.0000                    1.0000 9650.0000

# %%
df_test.shape
# Out:
# (966, 27)

# %%
df_test.head()
# Out:
#    Unnamed: 0    Age  Cholesterol  Heart rate  Diabetes  Family History  \
# 0           0 0.4944       0.2643      0.0623    0.0000          1.0000
# 1           1 0.2247       0.9536      0.0825    1.0000          0.0000
# 2           2 0.6292       0.0929      0.0642    0.0000          1.0000
# 3           3 0.4607       0.5679      0.0559    1.0000          1.0000
# 4           4 0.7191       0.4857      0.0229    1.0000          0.0000
#
#    Smoking  Obesity  Alcohol Consumption  Exercise Hours Per Week  Diet  \
# 0   1.0000   1.0000               1.0000                   0.3616     2
# 1   0.0000   1.0000               0.0000                   0.9965     2
# 2   1.0000   1.0000               0.0000                   0.9956     0
# 3   1.0000   1.0000               1.0000                   0.4373     0
# 4   1.0000   0.0000               1.0000                   0.5149     0
#
#    Previous Heart Problems  Medication Use  Stress Level  \
# 0                   0.0000          0.0000        8.0000
# 1                   1.0000          1.0000        5.0000
# 2                   0.0000          0.0000       10.0000
# 3                   0.0000          0.0000       10.0000
# 4                   0.0000          0.0000        7.0000
#
#    Sedentary Hours Per Day  Income    BMI  Triglycerides  \
# 0                   0.1944  0.5878 0.2835         0.3065
# 1                   0.3299  0.6029 0.4670         0.0870
# 2                   0.7801  0.3704 0.4094         0.2052
# 3                   0.7851  0.3682 0.9103         0.1636
# 4                   0.0709  0.7296 0.7589         0.5805
#
#    Physical Activity Days Per Week  Sleep Hours Per Day  Blood sugar  CK-MB  \
# 0                           1.0000               0.3333       0.2270 0.0482
# 1                           0.0000               0.1667       0.2270 0.0482
# 2                           7.0000               1.0000       0.1028 0.0027
# 3                           0.0000               0.6667       0.2036 0.0564
# 4                           5.0000               0.0000       0.2270 0.0482
#
#    Troponin  Gender  Systolic blood pressure  Diastolic blood pressure    id
# 0    0.0365    Male                   0.2839                    0.3721  7746
# 1    0.0365  Female                   0.7032                    0.4419  4202
# 2    0.0885    Male                   0.4581                    0.7791  6632
# 3    0.2718  Female                   0.7419                    0.2558  4639
# 4    0.0365    Male                   0.4129                    0.3953  4825

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966 entries, 0 to 965
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       966 non-null    int64
#  1   Age                              966 non-null    float64
#  2   Cholesterol                      966 non-null    float64
#  3   Heart rate                       966 non-null    float64
#  4   Diabetes                         935 non-null    float64
#  5   Family History                   935 non-null    float64
#  6   Smoking                          935 non-null    float64
#  7   Obesity                          935 non-null    float64
#  8   Alcohol Consumption              935 non-null    float64
#  9   Exercise Hours Per Week          966 non-null    float64
#  10  Diet                             966 non-null    int64
#  11  Previous Heart Problems          935 non-null    float64
#  12  Medication Use                   935 non-null    float64
#  13  Stress Level                     935 non-null    float64
#  14  Sedentary Hours Per Day          966 non-null    float64
#  15  Income                           966 non-null    float64
#  16  BMI                              966 non-null    float64
#  17  Triglycerides                    966 non-null    float64
#  18  Physical Activity Days Per Week  935 non-null    float64
#  19  Sleep Hours Per Day              966 non-null    float64
#  20  Blood sugar                      966 non-null    float64
#  21  CK-MB                            966 non-null    float64
#  22  Troponin                         966 non-null    float64
#  23  Gender                           966 non-null    object
#  24  Systolic blood pressure          966 non-null    float64
#  25  Diastolic blood pressure         966 non-null    float64
#  26  id                               966 non-null    int64
# dtypes: float64(23), int64(3), object(1)
# memory usage: 203.9+ KB

# %% [markdown]
# ## Промежуточный вывод после ознакомления с данными:
# * Тренировочный набор данных имеет:
#     * 8685 записей
#     * 27 столбцов + целевой признак
#     * Присутствуют пропуски
#
# * Тестовый набор данных имеет:
#     * 966 записей
#     * 27 столбцов
#     * Присутствуют пропуски
#
# 1) Часть данных нормализованы, это необходимо учесть в будущем.
# 2) Признак "Previous Heart Problems", может являться утечкой целевого признака.
# 3) Признак "Income" не является содержательным в контексте данного исследования

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# Ознакомимся с пропусками в данных

# %%
df_train.isna().sum()
# Out:
# Unnamed: 0                           0
# Age                                  0
# Cholesterol                          0
# Heart rate                           0
# Diabetes                           243
# Family History                     243
# Smoking                            243
# Obesity                            243
# Alcohol Consumption                243
# Exercise Hours Per Week              0
# Diet                                 0
# Previous Heart Problems            243
# Medication Use                     243
# Stress Level                       243
# Sedentary Hours Per Day              0
# Income                               0
# BMI                                  0
# Triglycerides                        0
# Physical Activity Days Per Week    243
# Sleep Hours Per Day                  0
# Heart Attack Risk (Binary)           0
# Blood sugar                          0
# CK-MB                                0
# Troponin                             0
# Gender                               0
# Systolic blood pressure              0
# Diastolic blood pressure             0
# id                                   0
# dtype: int64

# %%
missing_rows_train = df_train[df_train.isnull().any(axis=1)]
missing_rows_train
# Out:
#       Unnamed: 0    Age  Cholesterol  Heart rate  Diabetes  Family History  \
# 16            16 0.4494       0.4998      0.0632       NaN             NaN
# 90            90 0.3708       0.4998      0.0669       NaN             NaN
# 92            92 0.6292       0.4998      0.0733       NaN             NaN
# 185          185 0.5169       0.4998      0.0458       NaN             NaN
# 188          188 0.2697       0.4998      0.0357       NaN             NaN
# ...          ...    ...          ...         ...       ...             ...
# 8461        8461 0.7191       0.4998      0.0495       NaN             NaN
# 8509        8509 0.6517       0.4998      0.0367       NaN             NaN
# 8536        8536 0.6517       0.4998      0.0541       NaN             NaN
# 8619        8619 0.6067       0.4998      0.0596       NaN             NaN
# 8639        8639 0.6292       0.4998      0.0577       NaN             NaN
#
#       Smoking  Obesity  Alcohol Consumption  Exercise Hours Per Week  Diet  \
# 16        NaN      NaN                  NaN                   0.5021     3
# 90        NaN      NaN                  NaN                   0.5021     3
# 92        NaN      NaN                  NaN                   0.5021     3
# 185       NaN      NaN                  NaN                   0.5021     3
# 188       NaN      NaN                  NaN                   0.5021     3
# ...       ...      ...                  ...                      ...   ...
# 8461      NaN      NaN                  NaN                   0.5021     3
# 8509      NaN      NaN                  NaN                   0.5021     3
# 8536      NaN      NaN                  NaN                   0.5021     3
# 8619      NaN      NaN                  NaN                   0.5021     3
# 8639      NaN      NaN                  NaN                   0.5021     3
#
#       Previous Heart Problems  Medication Use  Stress Level  \
# 16                        NaN             NaN           NaN
# 90                        NaN             NaN           NaN
# 92                        NaN             NaN           NaN
# 185                       NaN             NaN           NaN
# 188                       NaN             NaN           NaN
# ...                       ...             ...           ...
# 8461                      NaN             NaN           NaN
# 8509                      NaN             NaN           NaN
# 8536                      NaN             NaN           NaN
# 8619                      NaN             NaN           NaN
# 8639                      NaN             NaN           NaN
#
#       Sedentary Hours Per Day  Income    BMI  Triglycerides  \
# 16                     0.4999  0.4949 0.4948         0.5036
# 90                     0.4999  0.4949 0.4948         0.5036
# 92                     0.4999  0.4949 0.4948         0.5036
# 185                    0.4999  0.4949 0.4948         0.5036
# 188                    0.4999  0.4949 0.4948         0.5036
# ...                       ...     ...    ...            ...
# 8461                   0.4999  0.4949 0.4948         0.5036
# 8509                   0.4999  0.4949 0.4948         0.5036
# 8536                   0.4999  0.4949 0.4948         0.5036
# 8619                   0.4999  0.4949 0.4948         0.5036
# 8639                   0.4999  0.4949 0.4948         0.5036
#
#       Physical Activity Days Per Week  Sleep Hours Per Day  \
# 16                                NaN               0.5046
# 90                                NaN               0.5046
# 92                                NaN               0.5046
# 185                               NaN               0.5046
# 188                               NaN               0.5046
# ...                               ...                  ...
# 8461                              NaN               0.5046
# 8509                              NaN               0.5046
# 8536                              NaN               0.5046
# 8619                              NaN               0.5046
# 8639                              NaN               0.5046
#
#       Heart Attack Risk (Binary)  Blood sugar  CK-MB  Troponin Gender  \
# 16                        0.0000       0.2332 0.0267    0.0008    1.0
# 90                        0.0000       0.1542 0.0047    0.0420    1.0
# 92                        0.0000       0.2569 0.0123    0.0008    0.0
# 185                       0.0000       0.5593 0.0067    0.0003    0.0
# 188                       0.0000       0.1126 0.0512    0.0005    0.0
# ...                          ...          ...    ...       ...    ...
# 8461                      0.0000       0.1383 0.0040    0.0032    1.0
# 8509                      0.0000       0.2391 0.0558    0.0608    1.0
# 8536                      0.0000       0.2767 0.0087    0.1504    1.0
# 8619                      0.0000       0.1561 0.0577    0.0006    0.0
# 8639                      0.0000       0.1482 0.0040    0.0680    1.0
#
#       Systolic blood pressure  Diastolic blood pressure    id
# 16                     0.3935                    0.2558  9528
# 90                     0.2581                    0.3372  9640
# 92                     0.2581                    0.2326  9515
# 185                    0.1742                    0.1512  9491
# 188                    0.2258                    0.1628  9448
# ...                       ...                       ...   ...
# 8461                   0.5484                    0.5581  9455
# 8509                   0.7290                    0.7791  9506
# 8536                   0.6065                    0.7907  9474
# 8619                   0.3871                    0.5000  9467
# 8639                   0.4839                    0.4535  9555
#
# [243 rows x 28 columns]

# %%
len(missing_rows_train['id'].unique())
# Out:
# 243

# %% [markdown]
# Для 243 пациентов из тренировочной выборки не указана часть данных

# %%
print(f'Пропущенные значения составляют {round(len(missing_rows_train) / len(df_train) * 100, 2)}% от тренировочного  датасета')
# Out:
# Пропущенные значения составляют 2.8% от тренировочного  датасета

# %%
missing_rows_test = df_test[df_test.isnull().any(axis=1)]

# %%
len(missing_rows_test['id'].unique())
# Out:
# 31

# %%
print(f'Пропущенные значения составляют {round(len(missing_rows_test) / len(df_test) * 100, 2)}% от тестового датасета')
# Out:
# Пропущенные значения составляют 3.21% от тестового датасета

# %%
missing_columns_test = df_test.columns[df_test.isnull().any()]
missing_columns_train = df_train.columns[df_train.isnull().any()]

# %%
missing_columns_test.isin(missing_columns_test).all()
# Out:
# np.True_

# %% [markdown]
# в обоих датасетах пропуски в одних и тех же столбцах

# %% [markdown]
# ***Количество пропусков составляет ~3% от общего объема данных, считаю, что их можно удалить. Так как восстановить медицинские данные пациентов проблематично.***

# %%
df_train = df_train.dropna()
df_test = df_test.dropna()
df_train = df_train.drop(columns=['Unnamed: 0', 'Income', 'Previous Heart Problems'])
df_test = df_test.drop(columns=['Unnamed: 0', 'Income'])

# %%
df_train['Gender'] = df_train['Gender'].map({
    'Male': 1,
    '1.0': 1,
    'Female': 0,
    '0.0': 0
})

# %% [markdown]
# **Чтобы продолжить исследование и не изменять исходный датасет, сделаем копию.**

# %%
train_copy = df_train.copy()

# %%
train_copy['Gender'] = train_copy['Gender'].map({
    'Male': 1,
    '1.0': 1,
    'Female': 0,
    '0.0': 0
})

# %%
print(train_copy['Gender'].unique())
# Out:
# [nan]

# %%
INTERVAL_COLS = train_copy.select_dtypes(include='number')
INTERVAL_COLS
phik = train_copy.drop('id',axis=1).phik_matrix(interval_cols=INTERVAL_COLS)

# %%
plt.figure(figsize=(17,15))
mask = np.triu(np.ones_like(phik, dtype=bool))
sns.heatmap(phik, annot=True, mask=mask, cmap='coolwarm')
# Out:
# <Axes: >

# %%
phik_pairs = (
    phik
    .where(~mask)  
    .stack()  
    .reset_index()
)

phik_pairs.columns = ['Признак 1', 'Признак 2', '$\\phi$ Корреляция']

phik_pairs_sorted = phik_pairs.sort_values(by='$\\phi$ Корреляция', ascending=False)

phik_pairs_sorted.head(10)
# Out:
#        Признак 1    Признак 2  $\phi$ Корреляция
# 10       Smoking          Age             0.6205
# 153  Blood sugar          Age             0.3595
# 155  Blood sugar   Heart rate             0.3582
# 189        CK-MB  Blood sugar             0.3372
# 209     Troponin        CK-MB             0.2844
# 208     Troponin  Blood sugar             0.2506
# 173        CK-MB   Heart rate             0.1417
# 171        CK-MB          Age             0.1386
# 190     Troponin          Age             0.1230
# 158  Blood sugar      Smoking             0.1156

# %%
model_dummy = DummyClassifier()
X = train_copy.drop(columns=['Heart Attack Risk (Binary)', 'id'])
y = train_copy['Heart Attack Risk (Binary)']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=TEST_SIZE, random_state=RANDOM_STATE)

# %%
X_train.head()
# Out:
#         Age  Cholesterol  Heart rate  Diabetes  Family History  Smoking  \
# 3120 0.1573       0.6143      0.0357    1.0000          1.0000   1.0000
# 2925 0.2697       0.4893      0.0330    0.0000          0.0000   0.0000
# 4251 0.4831       0.6143      0.0733    1.0000          1.0000   1.0000
# 4090 0.1348       0.8893      0.0467    0.0000          0.0000   1.0000
# 1350 0.2360       0.1857      0.0632    0.0000          0.0000   1.0000
#
#       Obesity  Alcohol Consumption  Exercise Hours Per Week  Diet  \
# 3120   0.0000               0.0000                   0.7547     0
# 2925   1.0000               1.0000                   0.4140     1
# 4251   0.0000               0.0000                   0.8478     0
# 4090   1.0000               0.0000                   0.7744     0
# 1350   1.0000               1.0000                   0.4815     0
#
#       Medication Use  Stress Level  Sedentary Hours Per Day    BMI  \
# 3120          0.0000        5.0000                   0.3088 0.2895
# 2925          0.0000        9.0000                   0.6120 0.6805
# 4251          1.0000        8.0000                   0.4788 0.6606
# 4090          0.0000        8.0000                   0.0353 0.4890
# 1350          0.0000        5.0000                   0.0551 0.7744
#
#       Triglycerides  Physical Activity Days Per Week  Sleep Hours Per Day  \
# 3120         0.6571                           2.0000               0.6667
# 2925         0.5896                           0.0000               0.8333
# 4251         0.7740                           3.0000               1.0000
# 4090         0.6377                           1.0000               0.6667
# 1350         0.6351                           7.0000               1.0000
#
#       Blood sugar  CK-MB  Troponin  Gender  Systolic blood pressure  \
# 3120       0.2270 0.0482    0.0365       1                   0.2258
# 2925       0.2270 0.0482    0.0365       0                   0.2065
# 4251       0.2270 0.0482    0.0365       1                   0.5806
# 4090       0.2270 0.0482    0.0365       1                   0.3161
# 1350       0.2270 0.0482    0.0365       1                   0.1871
#
#       Diastolic blood pressure    MAP
# 3120                    0.7907 0.6024
# 2925                    0.4419 0.3634
# 4251                    0.7558 0.6974
# 4090                    0.3605 0.3457
# 1350                    0.3721 0.3104

# %% [markdown]
# df_train['MAP'] = (1/3)*df_train['Systolic blood pressure'] + (2/3)*df_train['Diastolic blood pressure']

# %% [markdown]
# df_train['MAP']

# %% [markdown]
# Диета категориальный или порядковый, стресс тоже порядковый, диабет бинарный,Family History бинарный, Smoking бинарный, Obesity бинарный, Alcohol Consumption бинарный, Medication Use бинарный, Physical Activity Days Per Week порядковый, Gender бинарный,

# %%
ordinal_features = ['Diet', 'Stress Level', 'Physical Activity Days Per Week']
numerical_features = ['Age', 'Cholesterol', 'Heart rate', 'BMI', 'Triglycerides',
                      'Sleep Hours Per Day', 'Systolic blood pressure', 'Diastolic blood pressure', 'MAP']
binary_features = ['Diabetes', 'Family History', 'Smoking', 'Obesity',
                   'Alcohol Consumption', 'Medication Use', 'Gender']

# Препроцессинг
data_preprocessor = ColumnTransformer([
    ('num', StandardScaler(), numerical_features),
    ('ord', Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent', missing_values=np.nan)),
        ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
    ]), ordinal_features),
    ('bin', 'passthrough', binary_features)
])

# Финальный пайплайн
pipe = Pipeline([
    ('preprocessor', data_preprocessor),
    ('model', CatBoostClassifier(verbose=0, random_state=RANDOM_STATE))
])

# %%
df_train['Heart Attack Risk (Binary)'].value_counts()
# Out:
# Heart Attack Risk (Binary)
# 0.0000    5429
# 1.0000    3013
# Name: count, dtype: int64

# %%
scoring = make_scorer(recall_score)

# Параметры для перебора 
param_grid = [
    {
        'model': [CatBoostClassifier(verbose=0, task_type='GPU', class_weights=[1.0, 1.8])],  
        'model__iterations': [50],
        'model__learning_rate': [0.01, 0.1],
        'model__depth': [4, 6],
        'model__l2_leaf_reg': [1, 3],
        'model__border_count': [32, 64], 
    }
]


r_search = RandomizedSearchCV(
pipe,
param_distributions=param_grid,
n_iter=10,
scoring=scoring,
refit=True,
verbose=3,
cv=5,
random_state=RANDOM_STATE,
n_jobs=1)

# %%
# %%time
# Обучение
r_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=4, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.507 total time=   0.9s
# [CV 2/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=4, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.532 total time=   0.7s
# [CV 3/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=4, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.542 total time=   0.7s
# [CV 4/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=4, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.532 total time=   0.7s
# [CV 5/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=4, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.557 total time=   0.7s
# [CV 1/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=4, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.01;, score=0.552 total time=   0.7s
# [CV 2/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=4, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.01;, score=0.610 total time=   0.7s
# [CV 3/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=4, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.01;, score=0.675 total time=   0.7s
# [CV 4/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=4, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.01;, score=0.649 total time=   0.7s
# [CV 5/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=4, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.01;, score=0.713 total time=   0.7s
# [CV 1/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=4, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.01;, score=0.570 total time=   0.7s
# [CV 2/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=4, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.01;, score=0.621 total time=   0.7s
# [CV 3/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=4, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.01;, score=0.673 total time=   0.7s
# [CV 4/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=4, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.01;, score=0.643 total time=   0.7s
# [CV 5/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=4, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.01;, score=0.704 total time=   0.7s
# [CV 1/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=6, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.1;, score=0.493 total time=   0.7s
# [CV 2/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=6, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.1;, score=0.521 total time=   0.7s
# [CV 3/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=6, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.1;, score=0.501 total time=   0.7s
# [CV 4/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=6, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.1;, score=0.484 total time=   0.7s
# [CV 5/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=6, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.1;, score=0.500 total time=   0.7s
# [CV 1/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=6, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.01;, score=0.550 total time=   0.7s
# [CV 2/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=6, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.01;, score=0.540 total time=   0.9s
# [CV 3/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=6, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.01;, score=0.595 total time=   0.7s
# [CV 4/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=6, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.01;, score=0.575 total time=   0.7s
# [CV 5/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=6, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.01;, score=0.589 total time=   0.7s
# [CV 1/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=6, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.524 total time=   0.7s
# [CV 2/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=6, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.499 total time=   0.7s
# [CV 3/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=6, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.514 total time=   0.7s
# [CV 4/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=6, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.508 total time=   0.7s
# [CV 5/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=64, model__depth=6, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.480 total time=   0.7s
# [CV 1/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=4, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.01;, score=0.574 total time=   0.7s
# [CV 2/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=4, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.01;, score=0.582 total time=   0.7s
# [CV 3/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=4, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.01;, score=0.630 total time=   0.7s
# [CV 4/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=4, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.01;, score=0.641 total time=   0.7s
# [CV 5/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=4, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.01;, score=0.687 total time=   0.7s
# [CV 1/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=6, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.515 total time=   0.7s
# [CV 2/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=6, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.527 total time=   0.7s
# [CV 3/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=6, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.514 total time=   0.7s
# [CV 4/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=6, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.492 total time=   0.7s
# [CV 5/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=6, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.478 total time=   0.7s
# [CV 1/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=4, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.1;, score=0.539 total time=   0.7s
# [CV 2/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=4, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.1;, score=0.508 total time=   0.7s
# [CV 3/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=4, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.1;, score=0.514 total time=   0.7s
# [CV 4/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=4, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.1;, score=0.538 total time=   0.7s
# [CV 5/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=4, model__iterations=50, model__l2_leaf_reg=1, model__learning_rate=0.1;, score=0.565 total time=   0.7s
# [CV 1/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=4, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.535 total time=   0.7s
# [CV 2/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=4, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.523 total time=   0.7s
# [CV 3/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=4, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.521 total time=   0.7s
# [CV 4/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=4, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.542 total time=   0.7s
# [CV 5/5] END model=<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>, model__border_count=32, model__depth=4, model__iterations=50, model__l2_leaf_reg=3, model__learning_rate=0.1;, score=0.537 total time=   0.7s
# CPU times: total: 54.3 s
# Wall time: 41.7 s
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('num',
#                                                                                StandardScaler(),
#                                                                                ['Age',
#                                                                                 'Cholesterol',
#                                                                                 'Heart '
#                                                                                 'rate',
#                                                                                 'BMI',
#                                                                                 'Triglycerides',
#                                                                                 'Sleep '
#                                                                                 'Hours '
#                                                                                 'Per '
#                                                                                 'Day',
#                                                                                 'Systolic '
#                                                                                 'blood '
#                                                                                 'pressure',
#                                                                                 'Diastolic '
#                                                                                 'blood '
#                                                                                 'pressure',
#                                                                                 'MAP']),
#                                                                               ('ord',
#                                                                                Pipeline(steps=[('imputer',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('enco...
#                                               <catboost.core.CatBoostClassifier object at 0x00000234C1C223F0>)]),
#                    n_jobs=1,
#                    param_distributions=[{'model': [<catboost.core.CatBoostClassifier object at 0x0000023515BABEC0>],
#                                          'model__border_count': [32, 64],
#                                          'model__depth': [4, 6],
#                                          'model__iterations': [50],
#                                          'model__l2_leaf_reg': [1, 3],
#                                          'model__learning_rate': [0.01, 0.1]}],
#                    random_state=666,
#                    scoring=make_scorer(recall_score, response_method='predict'),
#                    verbose=3)

# %%
y_proba = r_search.predict_proba(X_test)[:,1]
y_pred = r_search.predict(X_test)

# %%
print("Лучшая модель:\n", r_search.best_estimator_.named_steps['model'])
print("Лучший результат:", round(r_search.best_score_, 4))
print('roc_auc', roc_auc_score(y_test,y_proba))
print('recall', recall_score(y_test,y_pred))
# Out:
# Лучшая модель:
#  <catboost.core.CatBoostClassifier object at 0x00000235156315B0>
# Лучший результат: 0.6421
# roc_auc 0.5110129953344947
# recall 0.6885474860335196

# %% [markdown]
# первый прогресс
# Лучшая модель:
#  <catboost.core.CatBoostClassifier object at 0x0000023511C4C110>
#
# Лучший результат: 0.6421
#
# roc_auc 0.5110129953344947
#
# recall 0.6885474860335196

# %%
cm =confusion_matrix(y_test,  y_pred)
sns.heatmap(cm, annot=True, fmt='.2f')
plt.ylabel('true values')
plt.xlabel('pred values');

# %%
import shap
catboost_model = r_search.best_estimator_.named_steps['model']
explainer = shap.TreeExplainer(catboost_model)
shap_values = explainer.shap_values(X_test)
shap.summary_plot(shap_values, X_test)

# %%
df_test['Gender'] = df_test['Gender'].map({
    'Male': 1,
    '1.0': 1,
    'Female': 0,
    '0.0': 0
})

# %%
test = r_search.best_estimator_.predict(df_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 test = r_search.best_estimator_.predict(df_test)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\pipeline.py:787, in Pipeline.predict(self, X, **params)
#     785 if not _routing_enabled():
#     786     for _, name, transform in self._iter(with_final=False):
# --> 787         Xt = transform.transform(Xt)
#     788     return self.steps[-1][1].predict(Xt, **params)
#     790 # metadata routing enabled
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\compose\_column_transformer.py:1090, in ColumnTransformer.transform(self, X, **params)
#    1088     diff = all_names - set(column_names)
#    1089     if diff:
# -> 1090         raise ValueError(f"columns are missing: {diff}")
#    1091 else:
#    1092     # ndarray was used for fitting or transforming, thus we only
#    1093     # check that n_features_in_ is consistent
#    1094     _check_n_features(self, X, reset=False)
#
# ValueError: columns are missing: {'MAP'}

# %%
y_proba_2 = r_search.best_estimator_.predict_proba(df_test)[:, 1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 y_proba_2 = r_search.best_estimator_.predict_proba(df_test)[:, 1]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\pipeline.py:903, in Pipeline.predict_proba(self, X, **params)
#     901 if not _routing_enabled():
#     902     for _, name, transform in self._iter(with_final=False):
# --> 903         Xt = transform.transform(Xt)
#     904     return self.steps[-1][1].predict_proba(Xt, **params)
#     906 # metadata routing enabled
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\compose\_column_transformer.py:1090, in ColumnTransformer.transform(self, X, **params)
#    1088     diff = all_names - set(column_names)
#    1089     if diff:
# -> 1090         raise ValueError(f"columns are missing: {diff}")
#    1091 else:
#    1092     # ndarray was used for fitting or transforming, thus we only
#    1093     # check that n_features_in_ is consistent
#    1094     _check_n_features(self, X, reset=False)
#
# ValueError: columns are missing: {'MAP'}

# %%
sns.kdeplot(y_proba_2)
sns.kdeplot(y_proba)
plt.tight_layout()
